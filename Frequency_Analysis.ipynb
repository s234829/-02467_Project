# %%
import os
import gzip
import json
import pandas as pd
import numpy as np
from collections import defaultdict
from joblib import Parallel, delayed
from tqdm import tqdm
from tqdm_joblib import tqdm_joblib
import pandas as pd
import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment import SentimentIntensityAnalyzer

import netwulf as nw
import networkx as nx
from networkx.readwrite import json_graph

import community as community_louvain
import matplotlib.pyplot as plt

import ast
from collections import defaultdict, Counter
import re

#for louvain algorithm
np.random.seed(seed=100)

# %%
with open("network.json", "r") as f:
    graph_data = json.load(f)

Graph = json_graph.node_link_graph(graph_data)
# Out:
# c:\Users\Friis\anaconda3\Lib\site-packages\networkx\readwrite\json_graph\node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(

# %% [markdown]
# # Partitioning into communities:

# %%
partition = community_louvain.best_partition(Graph)

# %%
communities = defaultdict(list)
for node, comm_id in partition.items():
    communities[comm_id].append(node)

communities = defaultdict(list, {
    k: v for k, v in communities.items() if len(v) > 10
})

for comm_id, members in communities.items():
    print(f"Community {comm_id}: {members}")
# Out:
# Community 0: ['B0002J58ME', 'B001F76OKC', 'B0042FDCMW', 'B00B5LIE4C', 'B003X2O79W', 'B00BSB9NDK', 'B006IRQU5S', 'B001OSC4FG', 'B00612FR1I', 'B003ULW71Q', 'B000U0C9UE', 'B00012FNBI', 'B000BR4UQ2', 'B000I2JCB8', 'B00012FNB8', 'B003AFPWI2', 'B07P67V245', 'B0089PCXAS', 'B0009WFFPO', 'B00R8HWMEU', 'B00KE77JJ4', 'B005BX3O0O', 'B00049QPII', 'B00FRPK4GI', 'B00HUAGZKW', 'B00247XURC', 'B00KASQQTQ', 'B000RL21OA', 'B003HC9JJ6', 'B00429C1QQ', 'B08MV1RJXG', 'B08M2M6WK2', 'B07K7SSSPM', 'B07KGJX6N7', 'B07KN9TM7K', 'B07KNB6D5F', 'B07G3KRYZK', 'B07DS8M656', 'B076ZS4LLX', 'B0765925D8', 'B00B2TWDWG', 'B00AZ2N906', 'B00IIOLQXU', 'B00QX5FAQA', 'B01GKKI38Y', 'B01BKTG026', 'B0044CM7YC', 'B00FMO7QIS', 'B00PRABXFO', 'B000059H6M', 'B0009WIY4S', 'B00FXCIS90', 'B00OZOIIYM', 'B00E8A0PNK', 'B0061S2T6S', 'B00R0HUEWK', 'B07DB1LKTH', 'B01M6ATZSG', 'B06Y12RK1V', 'B0012YN35M', 'B00MU1YEWW', 'B00007D00L', 'B00467182C', 'B00W85TAHE', 'B005GYXNT0', 'B000WC38CS', 'B00005N8AM', 'B0006BHP9M', 'B00006FMB2', 'B00009YXBK', 'B00005N913', 'B0069R218M', 'B002SSLY2A', 'B005IZUF3E', 'B00JJK06E2', 'B000EDWLUK', 'B00095NX9G', 'B07MYPDHMF', 'B002E58FSS', 'B00FCXVAUE', 'B001GIJRP4', 'B00B0C409Y', 'B000Z4KN1W', 'B001NFNFMQ', 'B00K1MPGBK', 'B00GVH3ZBC', 'B01N6L9TIQ', 'B07KLCRWF2', 'B01MSYL992', 'B005OL8NHW', 'B0046ZE3OE', 'B000PUAIOS', 'B000PUAIOI', 'B000AY6JVK', 'B000JJ4DF0', 'B00R6PE008', 'B001TK80FC', 'B009AVCAGC', '6301729897', 'B000WC38BO', '9089701834', 'B000069YWP', 'B000GEIRAU', 'B0895F5QK1', 'B07HGBM6GK', 'B01GKK1TPS', 'B01D41B21M', 'B0145NSQGW', 'B00L1T58HE', 'B000B5871I', 'B00095MBNK', 'B000FZETWK', 'B000067D1D', '6303243606', 'B000053UZS', 'B01MPXOPCD', 'B00P2HSBO8', 'B0002B55DO', 'B008SE9WPO', 'B00020HDFI', 'B000A3DGG2', 'B00CPYK0X6', 'B00KGIIF9E', 'B009904LQ6', 'B003HC9JIW', 'B00PR2IC8I', 'B009QMB1JC', 'B01GKKXXG6', 'B003SG8136', 'B00D2UMHWO', 'B000V6FVLG', 'B00FYYS9D2', 'B0051GLDQI', 'B0002444ZQ', 'B00BAGJB94', 'B000BZ5NWE', 'B00064VQWQ', 'B003QLEAQU', 'B00GXXTTJQ', 'B00I3MQ88U', 'B00080Z5FW', 'B001CCVFPO', 'B0028P4WJA', 'B001AYWY7C', 'B005VT6IYC', 'B0042DN4PO', 'B00CMPUEU2', 'B000AYELB0', '1882290062', 'B0031XYLWG', 'B00D2YCLF8', 'B0007TV63O', 'B004QSQMF4', 'B002FG9NC8', 'B001JXPBRE', 'B002W6ZXOS', 'B000WEVGHA', 'B0076OIFV4', 'B002FP9QBC', 'B0009WIY48', 'B009GGWWCS', 'B00HTQ7GQY', 'B003KO1JR6', 'B0000DI88C', 'B007KCONHM', 'B001L38SRW', 'B008DL4KFE', 'B0085Z3BWQ', 'B0010V60XY', 'B00023BLFI', 'B00Q5995LU', 'B0058M07US', 'B07BX7DPLW', 'B00ODASJOC', 'B00T40NWFC', 'B005NHQ1WQ', 'B001EJYCOG', 'B002Q3N2C2', 'B000S1MM8E', 'B001AZI236', 'B07QDPL686', 'B000PAU2ZS', 'B001TATL9G', 'B004VM2FKG', 'B004FPE41M', 'B001P5YIQQ', 'B002LSI1GY', 'B00A6HSWYI', 'B007QYB32M', 'B0000A2ZR7', 'B0006J021C', 'B008E6QMY0', 'B008CHFSSM', 'B008K6C270', 'B00062IWLQ', 'B07WHZYQT5', 'B000BRM992', 'B0013FGDGQ', 'B083Y1GB6G', 'B004PHE924', 'B001JGK4C8', 'B00KVPBWDS', 'B0072M7TMQ', 'B003MX5OSA', 'B0001DHSKG', 'B005NGKJW0', 'B0015FJYV0', 'B00005N8AN', 'B001HAO8NM', 'B000NA78S4', 'B00DYZ80WI', 'B004RL3H6C', 'B0006VY6JE', 'B0029KN8BC', 'B0013JRDZM', 'B00ESKSRL2', 'B0002F6B8I', 'B002JYPV7C', 'B0789TBY14', 'B0001DHSCO', 'B00BJ3AR78', 'B00008WFHE', 'B00F8M812E', 'B005XMFLS6', 'B00B1DC1CA', 'B000V5YP1O', 'B00AHKLZDY', 'B000CSTKJ2', 'B008X7JBPM', 'B00294Y722', 'B00ONT5DQU', 'B0041UUNU2', 'B006NKFAA6', 'B0051MKNUY', 'B00VJIIOSC', 'B003VQO524', 'B007VB8V7U', 'B01MD2DQ7V', 'B01MRE96NI', 'B0002D1252', 'B00DTWI6ZC', 'B0052T6XLY', 'B00B0C23SE', 'B000LSBXEI', 'B005QIOK52', 'B001AZI22W', 'B000LSBXES', 'B000RXZIHU', 'B07B5ZGGZ6', 'B00BD6JX8U', 'B001JXPBS8', '0981536328', 'B00E8A0OZ4', 'B001ONGL32', 'B0007QC938', 'B0046D8H4I', 'B01B800HQC', 'B001D261SY', 'B005HRNDH8', 'B0009VEESO', 'B00YIZWFQ0', 'B001W2HZ0S', 'B002EWD0BS', 'B000RG1HMM', 'B0001IXT90', 'B000N3T3Z2', 'B0008JHDIK', 'B000TJ6P7O', 'B003H8F3A4', 'B013HOZJCY', 'B001GP5TLI', 'B000W4TBNQ', 'B0159EZL78', 'B00BBFZI2I', 'B01MZ9Q0H0', 'B0042AM390', 'B00B1W0BQE', 'B00548OC66', 'B01C7YNT3Q', 'B00N35J8VQ', 'B0008IV4HC', 'B001ICUVPI', 'B008DL4L58', 'B000B5XPFQ', 'B00006HAX ...
# Community 1: ['B001JNNDRY', 'B001JV5BF8', 'B07QKVVKQH', 'B008UY8FKK', 'B00BY6XM5E', 'B006OAXL92', 'B004LWZW88', 'B004LWZWA6', 'B00JHH1ZN8', 'B002ZG98Z0', 'B07YTDDKSH', 'B08KBSH8PF', 'B008XK3LPA', 'B00009IB1D', 'B084WPWXJF', 'B0813VMVGM', '0767827813', 'B071CKB1RF', 'B01DX663IK', 'B00EPA3VA2', 'B0189HKELU', 'B00NYC5II0', 'B0057RCFQS', 'B00MP2FFL0', 'B00BEIYMZ6', 'B00003CXIP', 'B00A81MV3U', 'B0000VCZK2', 'B000A7DVR2', 'B000HEWEJO', 'B00MMPB6R2', 'B00005JPSM', 'B003ASLJO0', 'B000ICZD4I', 'B001O5LVPI', 'B0042816YK', 'B005F2JRUC', 'B00008G7UF', 'B0049B748M', 'B00005LOKR', 'B00AEFXK44', 'B00DDT0JB0', 'B001E75QH0', 'B0038M2AZA', 'B00407PNY2', 'B00AEFY0F2', 'B000P0J0EM', 'B0050MB43A', 'B0007UDC80', 'B00139W3NE', 'B00005JKU0', 'B00005JPT0', 'B003Q6D2B4', 'B00EL6AAEU', 'B000ATQYWY', 'B008GFI3EG', 'B000ERVJPY', 'B006MJEOIM', 'B00062IZ0Y', 'B000EBD9VC', 'B00080Z692', 'B000E1YW2W', 'B008QE9XD2', '0783226772', 'B001GLLLFK', 'B075FYTB5L', 'B0018O5WUA', '0783232047', 'B00005YNRH', 'B000A0GY0K', 'B000BR9SA0', 'B0002CX1NY', 'B00005K3OT', 'B004T47BTG', 'B000JQSHUK', 'B009NH6AOQ', 'B01BX7WUCO', 'B003EYVXZ0', 'B09XCP1673', 'B000PMLFRA', 'B0085Z8F4A', 'B00180IPM6', 'B002ZG988M', '0783113315', 'B005LAIII0', 'B004VWZPY4', 'B000W7GFG4', 'B005MYEPXC', 'B000BYRCQU', 'B0009IW894', '0783225903', 'B00595W3F6', 'B00013RCBG', 'B00GHH9HUE', 'B0044XV3R8', 'B00007LVCM', 'B000TFFNSU', 'B007I6TOIS', 'B012YPV0KM', 'B00049QQHI', 'B00462PTDQ', 'B0000AQS5E', 'B00HRYH67M', 'B0060MYL3E', 'B001TKUXUC', 'B01DVALT2I', 'B00003CXB4', 'B01F6EHOCG', 'B0030ATZI0', 'B0B5BJ41F4', 'B005GP7F8Y', 'B0001Z51LC', 'B0000DZ3G3', 'B09NRCZYY3', 'B07BQNMTKV', 'B0077T5SWC', 'B01LTI1RHQ', 'B00S1VR62K', 'B073R52XV7', 'B077P63937', 'B002AL2TYM', 'B00009NHC0', 'B003AWRM9M', 'B00A0HT99G', 'B011T0C73W', 'B00Z0GES3E', 'B007MDB548', 'B00AQ8IUJ4', 'B00EEBNCI8', 'B01F08XCIS', 'B012Y5OWRK', 'B00LO1SZ6A', 'B01BX7WVOG', 'B0012IX35S', 'B000R349GQ', 'B004N6WXEI', 'B00AKIPA52', 'B003NE8B6A', 'B005PPMI00', 'B000SINSYO', 'B004EYT8EC', 'B00GSMZ3I8', 'B01HPGE9LM', 'B00LBHODDG', 'B0091G7BTM', 'B015I145X8', 'B005LAII1C', 'B00F98FOPE', 'B001DJLD2G', 'B074GWVCX1', 'B00QRPZEIK', 'B004H0ZHD4', 'B002OAULQC', 'B0002B15WO', 'B00005T7HZ', 'B0007G89FU', 'B01MCXPQWX', 'B0000648Y6', 'B00YSBFH8C', 'B005SFR7YE', 'B000HT3PLK', 'B0108N9Q2Q', 'B00A8MGLAI', 'B002N8WLYK', 'B0000AQS0F', 'B005X5XIMO', 'B00AIBZKFG', 'B01BX2B1WY', 'B0007TKHDO', 'B00WV7TQDW', 'B00AEBB8OC', 'B008CFZQQS', 'B009AGEZKQ', '6304711905', 'B00936A0RU', 'B00D2CYU2W', 'B00GP382YC', 'B0002NY8XA', 'B012O29ISG', 'B006GRWCF2', 'B0117V8BX8', 'B00BEIYMIS', 'B00LG7VWIA', 'B01N3S0404', 'B013JBJ7EG', 'B00AY2DL78', 'B000CIF3U2', 'B06Y3K8ZX9', 'B0000AVHCA', 'B002WQ79A4', 'B0009S4IHO', 'B000HT3P60', 'B007S3GIM6', 'B008RJ6TTC', 'B000NOIX84', 'B000JLTRMC', 'B003BLPEHE', 'B07S86K91M', 'B00005JPL5', 'B01LTIBWTE', 'B0007WQGVI', 'B000HDRB6G', 'B00197YZ7C', 'B000KJU16Y', 'B00005QW6Y', 'B00005JL2W', 'B071NHCKHT', 'B0094V8OXG', 'B00AIBZFDI', 'B06XGG697H', 'B003YCI238', 'B0018RKEQO', 'B01D1U6V58', 'B00CDV4LEA', 'B0749W1Z5B', 'B000AP04LK', 'B002QFYJF4', 'B000X9FLKM', 'B0001YRVN4', 'B001DJLD12', 'B001RHGRPW', 'B001BGS16W', 'B00NGAJJAS', 'B0035Q636Q', 'B0053O89JM', 'B004EPYZDA', 'B001QIDTP8', 'B0030Y12FU', 'B09YLBH6QF', 'B001CTA1UM', 'B008Y1YKE4', 'B003WWDT1A', 'B00466HN72', 'B007C4ZJ0S', 'B0007CNY4K', 'B06ZXXC768', 'B00AYRIUOC', 'B005LAII62', 'B009YQJ322', 'B008YWY0HK', 'B009MB8Z5A', 'B00UCJ6TPE', 'B01I5SLS9A', 'B004LROMS4', '1559408685', 'B00HATD5P6', 'B000CRR3CY', 'B00KKZ4K1A', 'B005SYZYYK', 'B00JZYJ7F6', 'B009ERK1AE', '6305161984', 'B00BMJ7ZKG', 'B002DUJ9Q6', 'B07GJ35FH1', 'B00E9ZAU02', 'B071S71D4N', 'B0000V4906', 'B00004XPPE', 'B00HJQMFF6', 'B0026P3HPW', 'B000GI3RZ6', 'B00MA5KL9I', 'B00LMCDHMS', 'B000Q66J1M', 'B00D9BNONW', 'B08GLWBVDD', '0780623746', 'B075RT1NYK', 'B0045HCJJE', 'B01M0RLIC3', 'B00YB3KXZ4', 'B001KEHAGC', 'B00005N7Z0', 'B01B2CX0LU', 'B0038ZITIE', 'B00DS79HCE', 'B00005MP58', '6304698577', 'B000UX6TIY', 'B00VX21VR0', 'B005GP7EVC', 'B000LC4CVA', 'B00AEFYVMO', 'B002MU4NN ...
# Community 2: ['B00Z89L6JW', 'B00I3MOU4Y', 'B07FCSYS8G', 'B07N9KV8BX', 'B071G974CD', 'B011I2SXNO', 'B08QZN6LCM', 'B0B5M9RNVF', 'B09Q1NZQCH', 'B00NFDFBT4', 'B0091XI3YM', 'B01N7K1IUQ', 'B018HIZSIA', 'B001N3LLH4', 'B07B3R71YZ', 'B09KKKRSH7', 'B01MXMCG8P', 'B009ZQ8FQG', 'B00HTYU2XK', 'B00GDPU7G8', 'B06XBQYTPD', 'B00S65W70M', 'B003LFLOOW', 'B00L23V6V6', 'B00TREUVIG', 'B00EE3FVSU', 'B07ZDKF48M', 'B08VF7CR17', 'B01N1M2C3A', 'B000LJ94JI', 'B00N9US8DE', 'B01MTK18RW', 'B00QWUJMV0', 'B086TVB58L', 'B07DJBFGJL', 'B078HJXX55', 'B077YS5WSS', 'B014Y1ODBW', 'B09KNGP1BG', 'B00H71PBQ8', 'B01F4I1Q6E', 'B00HD6SDQW', 'B00147FVKW', 'B00RSGHX3Q', 'B00F4YK53Y', 'B000KDZSA4', 'B00MFDZJAG', 'B07TLM3QWG', 'B07B5Z2L2X', 'B079SL99L9', 'B07TJBHXV5', 'B07D7GNYX9', 'B0718ZDBBM', 'B08Z8CXGXC', 'B083LDRW9F', 'B072JPM6FL', 'B01KPATX3O', 'B01NCM8ZQF', 'B00BT0ZS52', 'B00GU9E17I', 'B09KHJRT4M', 'B07MGSGK67', 'B00KT1B7WK', 'B09NHNS5KB', 'B001M432XA', 'B07KGC9BCH', 'B001JIES4Q', 'B01GU87YE0', 'B07BN27TS1', 'B01I0QTS58', 'B014PCA5NK', 'B074N8MFJ3', 'B00YDQ5HBO', 'B0071UYJFE', 'B09W5P5T6G', 'B01MDTLXQN', 'B018GTUWPO', 'B017I3KWX6', 'B017AOY4WS', 'B00MFDOSFS', 'B00S949GPO', 'B0126KVVPY', 'B00XOX9QCS', 'B00J2PRBNS', 'B09GR3G9JY', 'B008RKGCQ6', 'B08FRS6LH1', 'B08HSKHJL4', 'B00HOQG9QW', 'B0068THAGY', 'B0043LOGCU', 'B07WFK2PF3', 'B00TYBB7D0', 'B00IGI3LMC', 'B019YFV80C', 'B09V2N5S93', 'B00CRWJ7VC', 'B000WHIIOQ', 'B00CDXOXB4', 'B00BOLQAKI', 'B002DJM9XC', 'B00BSBY38A', 'B00JH49OTS', 'B0B18G8R9B', 'B00XVQQ428', 'B01AB17IGQ', 'B00A6PD9I4', 'B00BHMETKC', 'B00BHU9BV6', 'B01J94BAVA', 'B00DNUF7KW', 'B00OCEDVW4', 'B01A1IZKLY', 'B016VLEH0A', 'B00ZA9SVU2', 'B06Y1H48K7', 'B00JJH33EU', 'B01MR6SLBR', 'B00Z89L9ZS', 'B06Y5S477B', 'B07G8P1G1L', 'B0035JRVBO', 'B00KQFMOVM', 'B00V4JKT52', 'B073X8BRNX', 'B00243IRWY', 'B004IAH7UE', 'B01K5CADJ0', 'B00GPY5Y92', 'B006MYGL8S', 'B00VRE938S', 'B003E8ZYGK', 'B00CDBQ9B8', 'B07MDSFVPZ', 'B08QGMNX1J', 'B00AVX0XOE', 'B00NB8ACD8', 'B075848T5T', 'B005R63QW6', 'B004RFV5OE', 'B008KSO622', 'B0162LLCA2', 'B00MFDMM3I', 'B0081L37Z0', 'B00COGXGNQ', 'B07P9CMY49', 'B01BD6AD10', 'B00775R45A', 'B009NNCHGU', 'B01NH0KRPW', 'B00F87ZUYG', 'B08L98MSX8', 'B07KLR41TS', 'B001DLYJK2', 'B019HQ6WWC', 'B001688V42', 'B01N1HH05H', 'B0794F687P', 'B07W5JVR3S', 'B08PC3Z8QM', 'B07BYSTXMF', 'B00CDBR1P6', 'B009NQKPUW', 'B00BGIBVP8', 'B00EIA6KEI', 'B09KHJQPKK', 'B014S0CC4E', 'B00RC1YRMC', 'B00DBT6SI0', 'B00ECU39AC', 'B01M5HAAFN', 'B000VU6K1C', 'B01GIIWVSG', 'B01LCCKPLI', 'B009TGWFQI', 'B007JUWM64', 'B006RZZD2C', 'B07BNSQ75X', 'B009CPJHY4', 'B0764T4989', 'B00V7MGF6S', 'B002T3A4KW', 'B01M2BZ6U4', 'B01LP9CBCE', 'B00V4JHNZG', 'B00ISJSPXY', 'B008ASLK8A', 'B07R8N7S6Y', 'B000HL2J0G', 'B00RF66GJQ', 'B072Z62L22', 'B004I0CTRU', 'B00NG3Z06C', 'B00KF8MCEE', 'B093CNZ7ST', 'B06XKSV3VZ', 'B01MQTROL1', 'B01M2C4NP8', 'B06WVFKQCY', 'B00RSGIVVO', 'B00I3MPDP4', 'B00932A2MC', 'B0815TD1VX', 'B00MH78O0M', 'B06Y1M57P4', 'B001H1SVZC', 'B009IJJ5B4', 'B07BKMY41B', 'B008Q0CE50', 'B01BID4MB0', 'B000HCYN18', 'B0088W9PD0', 'B00HUFALRK', 'B08XP4KH56', 'B0756VMDV5', 'B01BHDEHKM', 'B00JXVKDOK', 'B00AALL5IA', 'B008OKGZKM', 'B01B0DLHU2', 'B00944CJRK', 'B01I0QTVEQ', 'B01F4CAFVC', 'B00G4I11YQ', 'B01MYA9E5G', 'B017CDHRD0', 'B00KW27K4K', 'B0784YGPNS', 'B003G8Y4QO', 'B003JUGQ38', 'B003NQ1T62', 'B00005JPH2', 'B09J1LVQY6', 'B09HP8MB9G', 'B08LBNYTHY', 'B08DD6VDL5', 'B08L427DR9', 'B08QLXFCB4', 'B07XZN449Z', 'B003HIC564', 'B07N3VF1T4', 'B076KY88MY', 'B076XR2JF6', 'B076T9RS5F', 'B074P8B5ZP', 'B0747JZTZ4', 'B071WXLT4T', 'B0711Y5YZ8', 'B0716DT6G3', 'B071938BXX', 'B06XKJCJRV', 'B01MRX432N', 'B01MSD6M8L', 'B01N9BNM0Z', 'B01MRALWLZ', 'B01NAG5VL9', 'B01NARWGRS', 'B01M4HLAFR', 'B01MF5RN65', 'B01KZSCT14', 'B01JBARY4O', 'B01IURHTBC', 'B01LX0GTVD', 'B01E60ZAA4', 'B01EGW9GP2', 'B01AGY3ULK', 'B01C9I59QU', 'B015IVMF3K', 'B017HYSNWI', 'B01AIWSZK6', 'B018GZKKSC', 'B019969042', 'B017O65JXA', 'B013JPD8ZG', 'B014KMI1F4', 'B013WG1DFO', 'B00XOX6HLQ', 'B013WF2YYE', 'B00TEYPUIK', 'B010C2L4VE', 'B0035LSR56', 'B009AP51WS', 'B00RVBZP7Y', 'B00S6F35R6', 'B00TYB95I ...
# Community 3: ['B08DX1WFWK', 'B003PLRLFI', 'B0B6NHYWP9', 'B09W5MVF9F', 'B00N1JQ452', 'B004EPZ084', 'B004EPZ06G', 'B01MU9CMGJ', 'B07D5TTNQC', 'B09P49CRYV', 'B007K3JFUQ', 'B07VG6MFPV', 'B001N4ROW4', 'B006SVHOL8', 'B003L4Q0UQ', 'B0027TEADK', 'B00JJH254O', 'B006FLGBGA', '0792839730', 'B018FK66TU', 'B085P1BHQ8', 'B07B3HN24T', 'B002DJSBL6', 'B01M3U7GJH', 'B00005JL0I', 'B07T8K9YSH', 'B07TSDM7QD', 'B07SMBD3M4', 'B07J2TBSTX', 'B06XSYRDLR', 'B06XFVDZVY', 'B019YHGHX8', 'B006W0QOF2', 'B017WRCU92', 'B013EZQV6E', 'B00T484DKC', 'B00FEHXCIG', 'B088JW7CPS', 'B078JPXYFL', 'B07Q1K6NC5', 'B08NLFDCXZ', 'B000GOUMPI', 'B00H57OXSG', 'B000KWLRL4', 'B07RD8CKG8', 'B00TU9UFTS', 'B0765NR8MJ', 'B01LR7151C', 'B078HLD83H', 'B01489KUF8', 'B001O4Z8L2', 'B00V7WNHHI', 'B000MF4O82', 'B000IHL52W', 'B07L38J6MW', 'B00JWKDF1K', 'B07HS1J1BX', 'B001XVD2Z0', 'B002T9H2LA', 'B008COQGZY', 'B081TLJDFP', 'B09Q5YGY68', 'B01N1P9MYW', 'B001VLFE7G', 'B001NLCBJI', 'B09KFBM4X8', 'B09RSDTMK7', 'B09K1YRF44', 'B09FKQZP6H', 'B0035XQW74', 'B08WC6LC79', 'B00B0LPWU6', 'B077MJ13F8', 'B009M1AA6W', 'B00GT0MVIE', 'B0067XLHP6', 'B00B19DW0E', 'B003K05DQS', 'B0079LJZG8', 'B000P70I6Y', 'B017O65T9O', 'B00AOQ8GJ2', 'B003E88TKS', 'B00AHSFQMM', 'B00YIHM0G8', 'B073DL6Z1F', 'B07GFP9ZDV', 'B079XZPTZX', 'B07CJLYPZ9', 'B00RNRD7Y4', 'B0087UPMXU', 'B000GT4H0Y', 'B000S6GIK2', 'B0076HMMCY', 'B085NNRX6J', 'B07SZJ1MNR', 'B07HFF65N9', 'B00FJVBELO', 'B084SDJ2ST', 'B0000AOX0F', 'B0132TJCH2', 'B079NKRK66', 'B00M25DDQE', 'B07PH35NLY', 'B07CRRB5GQ', 'B0018T4GE8', 'B01AIW6KZS', 'B0B75XVF8W', 'B003V5CFV8', 'B00943SP0G', 'B00ESY6TKY', 'B00KYKMKKY', 'B07CPDKQCD', 'B08K2CHYK3', 'B07R4GGPRK', 'B09B8Q4BP9', 'B08LHJKJFN', 'B089RRLL12', 'B000OCY7IK', 'B000JU8H7E', 'B002DQSKLU', 'B000I9X6CW', 'B00950YEXU', 'B0896V9ZWC', 'B00IEPTXUG', 'B06Y1Q3PRW', 'B01MY6KAJP', 'B000I9YV3A', 'B004FHP9KA', 'B00TYB8YP4', 'B09CWF7QJ5', 'B00OSQA1Y2', 'B01CUVU7DQ', 'B075JVQHYL', 'B01JBAQNCS', 'B004NDDD04', 'B08V83JJBY', 'B000I9UA30', 'B00K2CHX9C', 'B008JFUN50', 'B001PYD0PC', 'B00GIVOXVW', 'B00112GVFO', 'B003NTSBTC', 'B011MUA592', 'B076QVB5HP', 'B018GVHDW2', 'B0114M90CQ', 'B00HUCF420', '0767802519', 'B004VL9Y5G', 'B07734STRN', 'B001EBWIPY', 'B00OTUC5RS', 'B00FWLDHSY', 'B000I55YV2', 'B09KK398BZ', 'B006INDMEE', 'B07215NWRL', 'B00ZHWD78I', 'B0016HMYEQ', 'B00ENYKBD0', 'B077NTKPWZ', 'B08L48LTPY', 'B074JKK68Z', 'B004EPYZUS', 'B005G4TJUC', 'B010R402L0', 'B01N0AN2W6', 'B004Z2TUGE', 'B00CCLPIAM', 'B000SW4E02', 'B000S6BKSC', 'B07DHYSBJ7', 'B08P7W4FL1', 'B07PM8ZWVK', 'B09HZ331JP', 'B005LAIIJY', 'B003QSGFG6', 'B00HQLF35I', 'B00190KZVY', 'B007OUFESC', 'B00GIXNAKU', 'B078TL6NHW', 'B007XF4J66', 'B00PRXDSEK', 'B0031ZG0WI', 'B0013WJGJ0', 'B001EC2ISA', 'B073HL8JW4', 'B00275EGWY', 'B095RR8QYD', 'B0B5NRBXQ6', 'B01GSUVGA8', 'B07G7DBTSN', 'B003QSGF0C', 'B0014C3KN2', 'B01MS27YUA', 'B009NQKXYK', 'B01IG0E1F0', 'B00AHSMDQY', 'B00EP0KBXM', 'B076KQVW67', 'B09LNDBGW6', 'B089XVJB9S', 'B00008PC0Y', 'B001RZPLMY', 'B00378VGGO', 'B000NDHQG0', 'B001GJ3BSC', 'B08MT15YX7', 'B01BLS9EVA', 'B01LWJF8I2', 'B00F35DI5Q', 'B001EBV0OY', 'B00UMD560E', 'B0002CHK1S', 'B07M7XQSSY', 'B0055B7IPE', 'B079GCVQX6', 'B074VZK5TS', 'B01489KX1O', 'B00ZVQRIH6', 'B00SY9NA9M', 'B00MQOXI8Y', 'B001EBV0OE', 'B004ZISVRW', 'B008N1LL42', 'B00ARAO720', 'B00AYB1RGG', 'B07YLP14JH', 'B01IURA6XA', 'B00PHK336G', 'B000NTMWYU', 'B00JPNZPCG', 'B07BL51Y9C', 'B003UYUQZW', 'B00O8NPCA8', 'B01MS4V81A', 'B001D0DR88', 'B06XDRTLNY', 'B003TO0VLW', 'B09RF4FR2T', 'B08BJYQ85R', 'B000I9W272', 'B07892V3VY', 'B001JYEMOQ', 'B00NM7K7NI', 'B07X7S9XJV', 'B000CDGVOE', 'B095KSZLRW', 'B005OK721G', 'B00YORD3PY', 'B008JFURII', 'B00TZ71J36', 'B0078Q2HAA', 'B000UAE7O0', '6305428409', 'B01MR52U7T', 'B000SW4DLM', 'B000HT3PBU', 'B018ILC3NE', 'B0014Z4OMU', 'B0017VT5E8', 'B081DZ57RF', 'B001THAS5K', 'B000P24FAE', 'B0B12HXM8W', 'B0014C0BMU', 'B00JB3AOEY', 'B004Q0IV2E', 'B000I9YUYU', 'B000CCW2U2', 'B0B8TMQCKB', 'B00A0SJWQU', 'B0813L8F8Y', 'B00K7WZMOK', 'B000RVK3QS', 'B08PDT92BN', 'B00HV8T8S4', 'B07B84ZTYK', 'B005LAIH54', 'B0011XF81G', 'B07SC9MSBN', 'B08KBJHCP ...
# Community 4: ['0767821556', 'B00008OE4W', 'B00B58FWYA', 'B078FBX7PD', 'B07MHJN972', 'B00FDV6VQI', 'B00G5G7K7O', 'B00LCL0XIA', 'B008N25XAE', 'B00480OC0C', 'B009MO57H6', 'B005LAIGW8', 'B00005JLG3', 'B07G1YKPPM', 'B01N97VC47', 'B00008DDIW', 'B00E6PUYJW', 'B00150N8EY', 'B00004WI57', 'B008U1ANHG', 'B06XNWXGDD', 'B009IV2Z3M', 'B0051T47NQ', 'B00008L3SY', 'B0711DDVZ4', 'B07G2DLVGB', 'B001H2ZHJ4', 'B00006SFKM', 'B00AASI5R2', 'B000TGUUFA', 'B002AL2TYC', 'B07QLR18MK', 'B004S8UTII', 'B004G5SOYO', 'B000BMY2L0', 'B00D9EJFV4', 'B004Z74X0M', 'B01MRH2QPD', 'B00HRUQ8HK', 'B0028AENVC', 'B0028ZDJF8', 'B0001I55UQ', 'B0155YRFZS', 'B093XKVJZ5', 'B00CEBJCF2', '0792843649', 'B0001IN0MQ', 'B000FVQLKW', 'B00GS8GM0K', 'B00KB8JB9M', 'B09RQ5X9DS', 'B06ZYJ4MYK', '6305120021', 'B0011Z1SK4', 'B01L08CLR0', 'B07HC3G9XC', 'B000CDSS22', 'B007RKFXQW', 'B075SV97P4', 'B002BWP49C', 'B00E44EZUE', 'B00DNF1RM4', 'B00006L931', 'B00S4YGWAQ', 'B000063K2R', 'B00KB3PZ60', 'B005LAIHPE', 'B000AJJMXW', 'B001OQCV56', 'B002ZHKZGA', 'B00M0JU2C0', 'B0042DN4UO', 'B000GRUQLA', 'B002WJI2QQ', 'B002WY65VU', 'B004LWZW8I', 'B002LVGXHK', 'B002ZG98LO', 'B018TNBX50', 'B0152AW1A4', 'B004EPZ07U', 'B005CFC0OM', 'B06X6G3V6W', 'B075CCX3GT', 'B01M3YG4R3', 'B09GT8C4P9', 'B07KLPTNQY', 'B07Q78VBNJ', 'B08JDM6MGK', 'B005G4TJI4', 'B074BYHTQF', 'B07YMFVS4P', 'B0718SV1PW', 'B0192PESGU', 'B000TGCR3I', 'B01E6CE17U', 'B00004R99B', 'B00005R1O8', '0783229372', 'B06ZYLHDFF', 'B000F1IQNM', 'B00004R99D', 'B073VDJMXP', 'B01LTHZVTM', 'B01LQV2Z7M', 'B01I2FFGW6', 'B076MG4TMW', 'B001BSBBDK', 'B0007P0Y7C', 'B0017JHQPK', 'B0034G4OYA', 'B001CW7ZZI', 'B002ZG97YM', 'B075QWMC34', 'B01MEED3V9', 'B01N7GQ8M5', 'B01K3EJVTI', 'B07VFQLNMD', 'B00009YXAW', 'B0000INU6S', 'B00AW0KHTM', 'B0000DZ3EE', '157362408X', 'B00LOCLBVU', 'B00FKPHPW6', 'B07DRXF9BK', 'B00LM4A21A', 'B06VY5PY1Y', 'B003H9M1QM', 'B0038N9X2W', 'B00018WNP6', 'B00R3MU8XM', 'B01IHT0DO8', 'B01IHSR1TY', 'B003156II4', 'B0059B05DW', 'B0776K3MYR', 'B0045HCJIK', 'B0112HPVEY', 'B01LXS0C52', 'B00860YICC', 'B001B3LILA', 'B00005JLIU', 'B015OVC1H4', 'B00N9QM6N6', 'B01CFB96EC', 'B00DNF1S28', '0790742829', 'B00DNLZRLU', 'B008IG0D00', 'B00STY5J82', 'B07H62Q4GM', 'B005K1VPY4', 'B003X2P9AS', 'B003Z94WC0', 'B001BAWKQU', 'B0000ZMGZW', 'B07378SXLG', 'B000R97FJI', 'B01LFSWCQU', 'B00003CX8Y', 'B0053O8AQE', 'B006MVKMTU', 'B00023P4TM', 'B00001MXXM', 'B004HZY8OS', '0783231172', '6305943389', 'B0001I55P6', 'B001TE6P78', 'B00466HN6S', 'B00005JMXX', 'B0009S2SOY', 'B000E5N6B6', 'B006P0FIGU', 'B005DVIPY4', 'B00009MEKB', 'B011E23A7C', 'B000QQKW1U', 'B00JGMIX70', 'B00H8W18EK', '078322947X', 'B00LKCQONE', 'B00O1D3C6Q', 'B00CSW0A8A', 'B00LOCLBWO', 'B001OQCV2E', 'B0034G4ORC', 'B076CF2TGR', 'B002CLKOXS', 'B004EPYZSU', 'B002GHHHKQ', 'B004QC6HKK', 'B005F3XV80', 'B005CFBZC0', 'B004ET9VNU', 'B008EFDC6M', 'B001993Y1S', 'B0000DZTNF', 'B08DK7KZQ8', '6305869103', 'B000FA57US', 'B002FOFX6U', 'B00AAMEY0U', 'B07QB9VYDM', 'B00CUDD0XO', 'B00AEFXDWI', 'B07FK73GH8', 'B077ZCTSX7', 'B00Q599952', '6305127646', 'B07HBK7CZV', 'B000096I9X', 'B0001I5632', 'B0019F0302', 'B01LFSWBAC', 'B00005JNBQ', 'B003NOGNR4', 'B009LDD26Q', 'B00O1D3C66', 'B09QYD78N2', 'B075L67RX1', 'B0009LS9Y4', 'B0056031NW', 'B00A6KQA6M', 'B01CKAGAK6', 'B00027JYLM', 'B07379KS9H', 'B000228EZY', 'B00005JKH9', 'B002VRNIZO', 'B00DYPZ44A', 'B017C22HGI', 'B0000694WH', 'B0002O7XW2', 'B0006IIPM6', 'B00023P4II', 'B00009NHC5', 'B001GCUO5M', 'B000FSME2E', '0790729628', 'B00005JMZK', 'B003NHMYHO', 'B00153ZR8G', 'B008R5SZY8', 'B008IG0DJQ', 'B000CEPE5A', 'B0047O2FPI', 'B0000A1HQP', 'B00005T30L', 'B000UX798I', 'B00003CXDD', 'B08Y1669KT', 'B00MQNHCQ4', 'B0009A409S', 'B0001BKBGG', 'B00003CWQ9', 'B003AWRMCO', 'B0001611DI', 'B00004W3HE', '6305772711', 'B079Y9111X', 'B07H9F1RZ6', 'B01EZFILNS', 'B00PA1V2CE', 'B0000VAGXU', 'B00005JKBC', 'B0764C2G1Z', 'B00GST8LMG', 'B000AAF1U4', 'B005CFC0L0', 'B005BXY1QU', 'B0716GNB3S', 'B001SGEUYW', 'B0000DZTIT', 'B00S89IRH8', 'B00US30XPG', '6305761078', 'B00015HVN8', 'B00005JN8S', 'B00OWGOZA4', 'B008JFUPPI', 'B000EXDSA2', 'B002I41KNC', 'B07X3QFWW ...
# Community 5: ['B019PQ0IWY', 'B01AH3QSEG', 'B002N57KG2', 'B00006JDRG', 'B01MV0KF7V', 'B071S7J7PV', 'B008LC8RKE', 'B00DZP1C2W', 'B0725X1SL7', 'B00WFN4MH2', 'B01LTI0BPU', 'B01FZ8I7R4', 'B01LBHSBUG', 'B00M7D82E4', 'B07K9HW9TT', 'B075FDF2DR', 'B07169PW2F', 'B0000E2FLB', 'B00HWWUQWQ', 'B0013527K2', 'B000BITVAG', 'B00YZBF1YU', 'B075FM7848', 'B00ZGDK2EU', 'B075FL83YJ', 'B01DEBC7Q6', 'B079P9BWR8', 'B0788XV93Y', 'B075F9PX8T', 'B01HH7KC60', 'B001AR0D40', 'B00456VHMA', 'B00005KHJP', 'B01DUHO4QU', 'B01N5RAO66', 'B000F7CEBG', 'B000HWZ4AC', 'B07FDQRKCR', 'B00006472U', 'B00G5G7EXY', 'B0033PSH86', 'B00P9UVCHQ', 'B07894WXX6', 'B00J11U54K', 'B001B9ZVVC', 'B018WXLHFI', 'B000J4QWIG', 'B00W6OOAAY', 'B00XQ142MW', 'B000058TIE', 'B00AFDN5Y0', 'B002DQL34G', 'B004IFYMXE', 'B00YHRMMLC', 'B07Q5CQ44V', 'B01J93C6LE', 'B00DW475CC', 'B000Q6GX5Y', 'B00005JNC2', 'B00IKM5LXG', 'B000H1RFQ4', 'B005HQBO9I', 'B00C1LIZI0', 'B00JHH22O4', 'B009AMAKWM', 'B0051PLR8S', 'B01KN66IME', 'B01IS31U6S', 'B01LTHZVSS', 'B00AEBB91E', 'B06XT9C1C9', 'B007A2O3FO', 'B000O599US', 'B071GRTQTN', 'B077HP62ZQ', 'B0714QRG4Z', 'B00FWSWM0Q', 'B001EPKKUK', 'B00MUI65OU', 'B00JAQJMJ0', 'B00347AIN0', 'B00JLDTA6W', 'B00IO03I6Q', 'B0000DZ3EG', 'B075FLCHWF', 'B0772SV5Q1', 'B07C8ZQM7G', 'B004XQO8VO', 'B00008CMT3', 'B014PIQYIO', 'B00VU4YO7K', 'B076HJZG8N', 'B008JFUNNM', 'B00AQTY3XA', 'B07HSKPDBV', 'B0743QPS8L', 'B01A53WR3Y', 'B00936A12O', 'B00I3C1T6G', 'B017RR4Y4Q', 'B013C6OUPO', 'B000G6BLGK', 'B075FMD4HG', 'B01LTHN5RW', 'B001CC7PM6', 'B075FM783H', 'B00NMYL93I', 'B0177ZM3LO', 'B09MDHD2TP', 'B00OY7YNKI', 'B00W1LATA2', 'B000G6BLHY', 'B008L3650W', 'B00BEIYH6U', 'B00UI5CRNU', 'B071CLL3PQ', 'B07GVXD8J2', 'B00KM9LY3Q', 'B00518A70E', 'B005ETANC2', 'B008TCF7WW', 'B01INUND9I', 'B01KYRX23U', 'B00DD2B52Y', 'B00WAEECI0', 'B01LTI0P24', 'B00002SSKI', 'B00CFB6OPM', 'B00EO10IEE', 'B00ICXM1UE', 'B07QLB785M', 'B002UD56I6', 'B002AT8KBU', 'B01KP7LAQ0', 'B00S4YGWD8', 'B0000DC3VM', 'B00BT2E9IM', 'B01BZ4DOGQ', 'B005G172Q8', 'B00264QI68', 'B00BEIYH1A', 'B07Z74Q34Y', 'B00RO49JC0', 'B01CTNDO58', 'B01A0IF20E', 'B00009IB1F', 'B003HKN548', 'B016QQZC90', 'B00005UMF5', 'B00008438U', 'B002P413IW', 'B01BHCPQXA', 'B00K2CHYHS', 'B00NGL7JRC', 'B00I462X7K', 'B01N2VLHE0', 'B004AHAEV4', 'B01DAFKE1Q', 'B0142WK5YM', 'B06W53FHJJ', 'B0049IHWYG', 'B01D9EUNB4', 'B013FAF96G', 'B00HLTD92E', 'B00004BZIY', 'B009PN18R2', 'B01LTHWTHY', 'B00WAJ8QXC', 'B07G235ZP9', '0783230478', 'B00J2PQYYK', 'B001HSNTKW', '0767810864', 'B00FRILRW0', 'B01LTHOAGC', 'B01LTHMF3M', 'B01BEDN0MG', 'B001P3SA9O', 'B0090XLDO0', 'B0017XOF50', 'B00STPQ6KQ', 'B01BLH8R50', 'B074ZVMJYS', 'B091KY9M3N', 'B01H4FJQZ8', 'B0053TWVDC', 'B00BEIYKSA', 'B00WW4CHYO', 'B00MI25Z8A', 'B01LTHO65M', 'B0034G4P3A', 'B00SU4PFZS', 'B00S2SYTR2', 'B0030A0ZD4', 'B0788XQ1BQ', 'B00553KAK2', 'B078FHJK18', 'B00M4ADWQ8', 'B01LTI1WAI', 'B00VKX6V9U', 'B00YHR5WSC', 'B00023P4UQ', 'B01LTHZVKG', 'B005GZ2CWS', 'B005Z9MFCM', 'B0009HLD4Q', 'B00PT3AUYO', 'B00NO834N0', 'B00KNVF2SG', 'B01I9KFVOW', 'B075FLJ8HP', 'B00Q3DLD68', 'B014U505R8', 'B001BSBBGC', 'B00F3TDA6O', 'B00K2CHUWW', 'B00HEPE6MM', 'B0B92CRJNX', 'B01M29CJYF', 'B00L16P1M4', 'B00HHYF5EI', 'B01NARNBUG', 'B00OALA8YS', 'B00PV17Z7E', 'B00E849QSG', 'B00CLF80KE', 'B00HXEWECI', 'B07BLHMY4K', 'B005SW2RTC', 'B001IZNIV4', 'B01LBHS9XA', 'B0044O1Q60', 'B007FQXEQO', 'B012XYP82U', 'B00Q3DMJZW', 'B00Y7R9H9M', 'B000BOH91S', 'B09YLDPBMZ', 'B074JQ8VH3', 'B0090SI53C', 'B00NP06FC4', '0767847431', 'B01LBWHR7Y', 'B00GHP8SH4', 'B000E1YW2C', 'B00NPHD5KC', 'B07RVHFLKK', 'B07ZWJNXTC', 'B01013FLNQ', 'B079ZSSHP2', 'B07B5RFSXV', 'B00X797NJW', 'B001HSNTGQ', 'B00KSEAMAG', 'B000LC4ZHQ', 'B00006IUFW', '0790731460', 'B01LBHS0I4', 'B01GUVOXIW', 'B008JFUPZI', 'B0169PXGLY', 'B07JYQTK85', 'B007P7UF06', 'B01G9AXWH2', 'B000A0GOEG', 'B07HSJWBY1', 'B00NT6NGT4', 'B00JLJ0AI8', 'B000I2J62I', 'B003GWE582', 'B001F7XHYI', 'B000MGBLJG', 'B00QX0IT36', 'B083XRCD6F', 'B005FY0FRE', 'B07731FMXQ', 'B00H4BHIGW', 'B00561BNHW', 'B00Q5998XK', 'B0038MUZ3O', '6305090580', 'B07BQP1G94', 'B00IGBI052', 'B00GAXASK8', 'B00005N5R ...
# Community 6: ['B019EQZSPC', 'B00UBRJ6MA', 'B00T54021E', 'B078WDQ19Q', 'B00KMGZPRK', 'B06XWWZ955', 'B073X9R3TQ', 'B003TNM2K6', 'B00N8MAH8C', 'B006GLLTL6', 'B003C27X44', 'B0797LG3ST', 'B00DPUB592', 'B00BLF9FOK', 'B00MU6B1E6', 'B00OLI95R6', 'B01N55Z7AZ', 'B00L83TMIE', 'B071F5H9ZR', 'B00FPWWCCC', 'B07MVP6LNW', 'B01351IDPO', 'B07FQW2519', 'B07HYS9D82', 'B00GYVPI42', 'B005NFJAWG', 'B01GPQND56', 'B003H54E20', 'B018SUHVPK', 'B074FBF974', 'B01A69R4MG', 'B0069W2N12', 'B017WXOTCW', 'B00DJYJRHG', 'B0749K8PFV', 'B01LXAH6SG', 'B01MTLWTRO', 'B073WDVJFS', 'B01FWXLXSM', 'B01MS8BFA5', 'B013JPIZGI', 'B01H2JPULU', 'B01N4EFBWI', 'B01GF6QQ0K', 'B01351H3PU', 'B00XQZX15M', 'B009ZQJ1G4', 'B00158K0R4', 'B01IS2OQ56', 'B00388PK7O', 'B013P6POO2', 'B00KUS5YGC', 'B00MP2FWC2', '0783240953', 'B00L8QOY0C', 'B00L8QOZ1A', 'B01FYI58F4', 'B00L8QP0AA', 'B004P1G6UI', 'B011U0HWEK', 'B01IH7RJGA', 'B01CF17X7O', 'B008Z9YLV2', 'B01FRFVVL4', 'B0076WUJU6', 'B00V8Z7HBQ', 'B00471JSRE', 'B00APJLX8E', 'B000UL087E', 'B018SVOIWS', 'B00N8MBYA2', 'B00FC1ZCB4', 'B00N8MCYM4', 'B00N8MA9VM', 'B001UTW7QU', 'B00ENBST8C', 'B00C7L8DM2', 'B0096CFQKC', 'B00MGFXUU4', 'B00EYY6TR6', 'B006QPX7UI', 'B00VRE9W7K', 'B00JP6UCFI', 'B00T480WDO', 'B0050UEVJ6', 'B005NFJAYE', 'B000T4EDXC', 'B005DN5BE4', 'B00IK67OQO', 'B00N1Q6BG2', 'B00JM04P9Q', 'B0026Y88RU', 'B003DRHV40', 'B000LV6OJE', 'B000SW2EQS', 'B007G5GMMC', 'B000AQ69QI', 'B003XQRZ56', 'B0050PYNP8', 'B00FPGV3RS', 'B00177YA1K', 'B00008K76U', 'B001993Y4K', 'B005LAIIMG', 'B0001NBMH6', 'B0090XO59U', 'B000I2J2XG', 'B00821OX98', 'B003EYEEI8', 'B0038EG20W', 'B00BEZTMQ8', 'B00ARWXJ54', 'B007Z9QP3K', 'B001KOFH2G', 'B06XGVSVKN']
# Community 7: ['B01LYYSQLS', 'B09KGMSNJR', 'B08Z8BMXD3', 'B08B4X9LNX', 'B08ZT5Q1M1', 'B08ZJNB6W1', 'B08YGLVGT5', 'B08G3QQR6R', 'B08F3QX875', 'B08NSHKQ8F', 'B08LPWP2F2', 'B08D77K4DL', 'B088P9ZGY6', 'B08B3FTN15', 'B08FWB2RSG', 'B089994YNC', 'B086QKC2GZ', 'B088FT6KRV', 'B08439ZWH2', 'B0813Y7MQS', 'B074HR3175', 'B087BXG4ZB', 'B084NT4K3L', 'B086ZVCMS7', 'B07T7KX63S', 'B083QL6B7D', 'B086HBKHV4', 'B085C1NS48', 'B07T7LK9VS', 'B078ZHZ9GV', 'B086181SJ5', 'B07NWBVKV3', 'B08434RY3K', 'B07ZQGTNVZ', 'B07Y9964HJ', 'B081S6VB3F', 'B07T89B2KQ', 'B07V2JMKFD', 'B07ZQGYLPV', 'B07ZDHY5MC', 'B07YSQ8S6R', 'B07SMB6Q8N', 'B07T9C2L1M', 'B07GQ67X5H', 'B07TGF7YLM', 'B07TD8BZ29', 'B07CRY6YMX', 'B07V3WCJ9J', 'B07T2V734J', 'B07P763HT4', 'B07P9S8JTG', 'B07Q4ZKJCD', 'B07NRR24TF', 'B07FBTQGZS', 'B07B4N19NX', 'B07N133Q86', 'B07MV93DJJ', 'B07MXK64BY', 'B07G927QGL', 'B07JCV1STZ', 'B07JDWNQGL', 'B07749H2JD', 'B07FZPC4CT', 'B0769FCSQ5', 'B07GBFV35G', 'B07BCDVFD7', 'B07BCZBJZF', 'B0767HBJ53', 'B07BR8YLM2', 'B06XNK2H6Z', 'B074V2XN1B', 'B0764KD2K8', 'B00M8MN0D2', 'B01M3XV3CE', 'B06X6BCLYS', 'B01E7XW7MY', 'B01MUX5XUN', 'B01N2IJE43', 'B01MU7R5PH', 'B01LWY9DNT', 'B00498XRPE', 'B09LZ2NXJF', 'B016DR2VLY', 'B09R8QPB93', 'B01GEWSWI4', 'B086HN2HRK', 'B01EGW8UIG', 'B003CWTIO2', 'B016DR2YZ2', 'B01GDH9WLG', 'B08J9R44VK', 'B082FY19T6', 'B086H2XHPG', 'B07NYCP3X3', 'B07KX9ND9J', 'B01MQISJ78', 'B009CG9P1S', 'B071GM6G1Y', 'B083ZPTBF3', 'B01MQMJIK3', 'B07BSCR3CY', 'B07648FFWS', 'B01MUR5CVX', 'B079MHS43X', 'B007QIDH9A', 'B01ENS7OLM', 'B008Q00LFK', 'B07B4SGC2T', 'B074HXJ16M', 'B01LRN87TY', 'B0042QZSRS', 'B00XVQQV5I', 'B01HUY1QUG', 'B07T8CBKBB', 'B07YBMWHY4', 'B06XXYQTN2', 'B00QF2V24A', 'B001TM5B16', 'B07P173V8F', 'B083VRKR6K', 'B0842JTKNF', 'B07ZS2SDXH', 'B07S64HKRF', 'B07QV7BHXX', 'B06W2K76V3', 'B07KPVYBX9', 'B07L1ZH5N8', 'B01I4DHBL0', 'B074V1R7G3', 'B08PPZ2D1W', 'B08P22QK9B', 'B08LMBNDYZ', 'B09C4DY7BN', 'B08VGN5QFC', 'B0788WKQ39', 'B07BPFB594', 'B00XVQM9HC', 'B01M7WYEC1', 'B08CYB921D', 'B07C167TN8', 'B07XJ9L7YG', 'B01GOPAHNO', 'B019YLL6D0', 'B01E7XW742', 'B0095R4LV8', 'B01HUY2ID0', 'B008S2BZ10', 'B08P9MSL4B', 'B078JNZHNZ', 'B01FEBMZH0', 'B06XKCN462', 'B000VEPL2M', 'B07BRPW6D6', 'B07GN4M655', 'B077PY6YQ8', 'B00STYNVNC', 'B01J6ZDWWM', 'B07ZMMYSSR', 'B00715RP8C', 'B01H2BJSJI', 'B086CYX97H', 'B07KBF1S2L', 'B00C2QUCBM', 'B016DMY3HE', 'B003TNM2ME', 'B000GOUXES', 'B07F939NG4', 'B01GEWR81G', 'B005721Y7Y', 'B0035JGZAC', 'B088Q2THKZ', 'B01M8NHFSS', 'B06Y3LS5GN', 'B06ZYR7317', 'B01KH1J32M', 'B00STZXFLO', 'B016DR2XVM', 'B078P1F2TG', 'B005DNBE36', 'B01N6VIWXM', 'B01MXMZOTN', 'B01GT3R6JE', 'B01A1F5GTI', 'B01ENS7J3K', 'B016DR2WUE', 'B0786FCHHT', 'B084CVC64N', 'B07K2JK4RW', 'B07GX4YNJY', 'B004742Y3G', 'B07PZF38V7', 'B091JFF24Q', 'B01GRU59XE', 'B0757FYKH4', 'B07GS8YFYY', 'B08KC41MQ4', 'B00KGJNIOU', 'B07ZDKMFY7', 'B001FD5KJM', 'B087MW5JG4', 'B07SRDCBGB', 'B076BQ4LXG', 'B071JV6R9D', 'B08W3LJZWQ', 'B01MPXT1T3', 'B074PMZGRF', 'B01KYFIHOQ', 'B016DPDAHK', 'B07YBNKVZ8', 'B077J4KP5R', 'B01ERXLRHU', 'B07HXNVT3F', 'B076D4PSYF', 'B00M5MBOG0', 'B07R6PH91X', 'B07CK21ZDZ', 'B076GHVJXZ', 'B0B5JD6592', 'B08NPMYK2M', 'B08ZJZLZ9V', 'B0B8QP1TZG', 'B08RW9VB3N', 'B08QMPTNQQ']

# %% [markdown]
# Community 1 and 2 are still very large so we should split those into subgraphs to try and find more meaningful communities:

# %%
def print_community_sizes(community_dict):
    for community_id, asin_list in community_dict.items():
        print(f"Community {community_id}: {len(asin_list)} items")

print_community_sizes(communities)
# Out:
# Community 0: 1050 items
# Community 1: 17149 items
# Community 2: 13726 items
# Community 3: 911 items
# Community 4: 615 items
# Community 5: 491 items
# Community 6: 115 items
# Community 7: 223 items

# %%
community1_sub_nodes = [node for node, comm in partition.items() if comm == 1]
community2_sub_nodes = [node for node, comm in partition.items() if comm == 2]

# Extract subgraph
subgraph1 = Graph.subgraph(community1_sub_nodes).copy()
subgraph2 = Graph.subgraph(community2_sub_nodes).copy()

# Run Louvain again on the subgraph
subgraph1_communities = community_louvain.best_partition(subgraph1)
subgraph2_communities = community_louvain.best_partition(subgraph2)

# %%
# First sub graph:
sub_communities1 = defaultdict(list)
for node, comm_id in subgraph1_communities.items():
    sub_communities1[comm_id].append(node)

sub_communities1 = defaultdict(list, {
    k: v for k, v in sub_communities1.items() if len(v) > 10
})

# Second sub graph:
sub_communities2 = defaultdict(list)
for node, comm_id in subgraph2_communities.items():
    sub_communities2[comm_id].append(node)

sub_communities2 = defaultdict(list, {
    k: v for k, v in sub_communities1.items() if len(v) > 10
})

# %%
def merge_communities_sequential(partition, sub_communities1, sub_communities2, min_size=10):
    final = {}
    used_nodes = set()

    # Step 1: Add original communities, excluding 1 and 2
    original_communities = defaultdict(list)
    for node, comm_id in partition.items():
        if comm_id not in {1, 2}:
            original_communities[comm_id].append(node)

    for comm_id, nodes in original_communities.items():
        unique_nodes = [n for n in nodes if n not in used_nodes]
        if len(unique_nodes) >= min_size:
            final[comm_id] = unique_nodes
            used_nodes.update(unique_nodes)

    # Step 2: Add sub-communities from the two splits
    next_id = max(final.keys(), default=0) + 1
    for nodes in list(sub_communities1.values()) + list(sub_communities2.values()):
        unique_nodes = [n for n in nodes if n not in used_nodes]
        if len(unique_nodes) >= min_size:
            final[next_id] = unique_nodes
            used_nodes.update(unique_nodes)
            next_id += 1

    return dict(final)

communities = merge_communities_sequential(
    partition,          # Original
    sub_communities1,   # From splitting community 1 
    sub_communities2,   # From splitting community 2
    min_size=1000
)

#We are left with the 6 largest communities in the graph:
print_community_sizes(communities)
# Out:
# Community 0: 1050 items
# Community 1: 1580 items
# Community 2: 3928 items
# Community 3: 3757 items
# Community 4: 2475 items
# Community 5: 1669 items
# Community 6: 1230 items

# %% [markdown]
# # Finding top movie titles in each community based on genre:

# %%
#This function parses the categories column, we will use this later to construct a whitelist
#of terms to catch genres:
def extract_unique_category_terms(df, column='categories'):
    all_terms = set()
    
    for raw_entry in df[column].dropna():
        try:
            # If the entry is stringified like a list, we safely convert it back to a list
            parsed = eval(raw_entry)
            if isinstance(parsed, list):
                all_terms.update(parsed)
        except Exception as e:
            print(f"Error parsing entry: {raw_entry}, Error: {e}")
    
    return all_terms

# %%
df = pd.read_csv("Merged_Reviews_and_Metadata.csv")
all_category_terms = extract_unique_category_terms(df)
# Out:
# C:\Users\Friis\AppData\Local\Temp\ipykernel_6516\1327975619.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Merged_Reviews_and_Metadata.csv")

# %%
#These are all unique terms in the column:
print(all_category_terms)
# Out:
# {'Malicious', 'Warner Home Video', 'Joel, Billy', 'Special Interests', 'Nail-Biting', 'All Sony Pictures Titles', 'MTV', '20th Century Fox Home Entertainment', 'Strange', 'Movies & TV Halloween Store', 'Contemplative', 'Introspective', 'Queen', 'Classics Kids Love', 'MGM Home Entertainment', 'Criterion Collection', 'Dreamlike', 'Harrowing', 'Discovery Channel', 'Studio Specials', 'Drama', 'Joyous', 'Fully Loaded DVDs', 'All', 'Anime', 'Monthly Deals', 'Military and War', 'The Comedy Central Store', 'Westerns', 'Dark', 'Adventure', 'Shakespeare on DVD Store', 'Educational', 'Family Features', 'Fox Featured Deals', 'Warner DVD & Blu-ray Deals', 'Exotic', 'All HBO Titles', 'Disney Channel', 'Fitness & Yoga', 'All FX Shows', 'Historical', 'Prince', 'Science Fiction & Fantasy', 'Timeless Holiday Favorites', 'Yoga', 'Television', 'Harry Potter and the Goblet of Fire', 'MOD CreateSpace Video', 'Box Sets', 'Art House & International', 'The Big DVD Sale', 'Oscar Nominees', 'Emmy Nominees', 'Oscar Central', 'Futuristic', 'Outrageous', 'All Sci Fi Channel Shows', 'Movies', 'Upbeat', 'Campy', 'Aliens', 'International', 'Kids & Family', 'Crow, Sheryl', 'Thoughtful', 'Pink Floyd', 'British Television', 'Harry Potter and the Prisoner of Azkaban', 'The Histories', 'New Line Platinum Series', 'Harry Potter and the Half-Blood Prince', 'Explore 50 Years of Great TV', 'Aguilera, Christina', 'Music Videos and Concerts', 'Lionsgate DVDs Under $10', 'Cartoon Network', 'Boxed Sets', 'Batman Animated Movies', 'Other Instructors', 'Mystical', 'Exercise & Fitness', 'Animation', 'Disney Channel Original Movies', 'Inspirational', 'Intense', '4-for-3 DVD', 'HBO', 'Golden Globe Winners', 'Sci-Fi & Fantasy', 'Sober', 'Comedy', 'Past Golden Globe Winners', 'Stand Up', 'X-Men', 'Superman Animated Movies', 'Lionsgate Home Entertainment', 'Philosophical', 'Family Friendly', 'Godzilla', 'King, B.B.', 'Tense', 'All MTV', 'All BBC Titles', 'Sophisticated', 'Kids', 'Mystery & Suspense', 'Quirky', 'Lifetime Original Movies', 'Edifying', 'Downbeat', 'Scooby Doo', 'Star Wars', 'Faith & Spirituality', 'Blaxploitation', 'Talk Show and Variety', 'Holocaust', 'Fun', 'Birth-2 Years', 'Optimistic', 'Modern Adaptations', 'Sad', 'Two-Disc Special Editions', 'Emmy Central', 'DreamWorks', 'Imaginative', 'Collections', "Father's Day", 'Music Artists', 'Tenacious D', 'Compelling', 'Bowie, David', 'Harry Potter', 'Harry Potter and the Order of the Phoenix', 'Osbourne, Ozzy', 'Musicals & Performing Arts', 'Stephen Lynch', 'History', 'Silent Films', 'The Comedies', 'Docurama', 'Weird Al', 'Historical Context', 'Sony Pictures Classics', 'Arthouse', 'Electrifying', 'History Channel', 'Anchor Bay Deals', 'Miniseries', 'Haggard, Merle', 'Scooby Doo Animated Movies', 'Sci-Fi Action', 'Top Sellers', 'Holiday, Billie', 'Bee Gees', 'Art & Artists', 'Confused', 'Warner Bros. Featured Deals', 'Sentimental', 'Biography', 'Sensual', 'Sassy', 'Arts, Entertainment, and Culture', 'HBO Deals', 'Gritty', 'Dylan, Bob', 'DC Universe Animated Original Movies', 'Emerson, Lake & Palmer', 'Sweet', 'Independently Distributed', 'Young Adult Audience', 'Ambitious', 'The Big DVD & Blu-ray Blowout', 'Charming', 'Horror', 'Fitness', 'Collections & Documentaries', 'Military & War', 'Vista Series', 'All Lionsgate Titles', 'Music Video & Concerts', 'Stunning', 'LGBTQ', 'A&E Home Video', 'All MGM Titles', 'Miramax Home Entertainment', 'Outlandish', 'Playful', 'Lionsgate DVDs Under $20', 'Romance', 'Holidays & Seasonal', 'Reality TV', 'Foreign Spotlight', 'Understated', 'All Disney Titles', 'Warner Sale', 'Powerful', 'Cooper, Alice', 'Scary', 'BBC', 'Musicals', 'Lionsgate Indie Selects', 'All Made-for-TV Movies', 'Wall-E', 'Music Videos & Concerts', 'Prime Video', 'Suspense', 'Eerie', 'Romantic', 'Unscripted', 'Easygoing', 'Essential Art House', 'The Beatles', 'Metallica', 'Foreign Films', "Editor's Picks", 'Paul McCartney', 'Movies & TV', 'Sting', 'Fox TV', 'Beautiful', 'Rush', "Today's Deals", 'Movies & TV Holiday  ...

# %%
#Helper function to speed up the next code block
def build_asin_to_categories(df):
    """Preprocess the dataframe to create a fast lookup dictionary."""
    asin_to_categories = {}
    for _, row in df.iterrows():
        asin = row['parent_asin']
        try:
            categories = ast.literal_eval(row['categories']) if pd.notna(row['categories']) else []
        except (ValueError, SyntaxError, TypeError):
            categories = []
        asin_to_categories[asin] = categories
    return asin_to_categories

asin_to_categories = build_asin_to_categories(df)

# %%
# Using an LLM to parse for genre-like terms + manual curation to get the list:
valid_genres = [
    'action', 'adventure', 'comedy', 'drama', 'fantasy', 'sci-fi', 'science fiction',
    'horror', 'thriller', 'romance', 'mystery', 'animation', 'documentary', 'family', 
    'musicals', 'biography', 'historical', 'crime', 'music', 'war', 'western', 'kids', 
    'educational', 'reality', 'anime', 'fitness', 'yoga', 'exercise', 'sports', 
]

# This function counts the number of matches from valid_genres in the categories column
# for a certain community:
def get_top_genres_for_community(community_asins, asin_to_categories, top_n):
    genre_counter = Counter()

    for asin in community_asins:
        categories = asin_to_categories.get(asin, [])
        for cat in categories:
            cat_lower = cat.lower()
            for genre in valid_genres:
                if genre in cat_lower:
                    genre_counter[genre] += 1

    return dict(genre_counter.most_common(top_n))

# Try it out here by putting in a community id:
# We can also use this code to get some future plots of the actual statistics
# If that makes sense, like make a for loop for each id.
community_id = 1
asin_list = communities[community_id]
top_genres = get_top_genres_for_community(asin_list, asin_to_categories, 10)
print(top_genres)
# Out:
# {'action': 168, 'adventure': 140, 'science fiction': 122, 'comedy': 120, 'drama': 117, 'fantasy': 80, 'family': 77, 'kids': 74, 'war': 71, 'music': 51}

# %%
#Future code we will use to make the image plots:

# Load the metadata dataset that contains image URLs
meta_df = pd.read_csv('meta_Movies_and_TV_Full.csv')

asin_to_image = {}

for _, row in meta_df.iterrows():
    asin = row['parent_asin']
    image_data = row['images']
    
    # Check if the image_data is a list of dictionaries
    if isinstance(image_data, str):
        try:
            image_urls = eval(image_data)
            for image in image_urls:
                if isinstance(image, dict):  # Check if it's a dictionary
                    if 'large' in image:
                        asin_to_image[asin] = image['large']
                        break
                    elif '360w' in image:
                        asin_to_image[asin] = 'no image' #These images aren't very good so left out
                        break
        except (ValueError, SyntaxError, TypeError):
            continue
# Out:
# C:\Users\Friis\AppData\Local\Temp\ipykernel_6516\3658760075.py:2: DtypeWarning: Columns (2,4,7,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_df = pd.read_csv('meta_Movies_and_TV_Full.csv')

# %%
# We can grab the image URL for any ASIN here, only works for "Movies", Prime Video 
# Doesn't have proper images but random stills from the movie, left out for now.

asin_example = 'B001JV5BF8'
image_url = asin_to_image.get(asin_example, 'Invalid Key')
print(f"Image URL for ASIN {asin_example}: {image_url}")
# Out:
# Image URL for ASIN B001JV5BF8: https://m.media-amazon.com/images/I/515qo5iCUzL.jpg

# %%
# This code uses regular expressions to filter out titles in order to avoid duplicates
# In the get_top_titles functions:
def normalize_title(title):
    if not isinstance(title, str):
        return ''
    title = title.lower()
    
    # Keep part after comma if it exists and the part after is short (likely the title)
    if ',' in title:
        parts = title.split(',')
        if len(parts[1].strip().split()) <= 4:
            title = parts[1]
    
    title = re.sub(r'\[.*?\]', '', title)              # remove [DVD], [Blu-ray], etc.
    title = re.sub(r'\(.*?edition\)', '', title)       # remove (Special Edition), etc.
    title = re.sub(r'\(.*?format\)', '', title)        # remove other bracketed formats
    title = re.sub(r'[^a-z0-9\s]', '', title)          # remove punctuation
    title = re.sub(r'\s+', ' ', title).strip()         # normalize whitespace
    return title

# Simply returns the top titles, based on the rating_number
# Probably not going to use this function much, but it's nice to have.
def get_top_titles_for_community(community_asins, df, top_n=10):
    df['rating_number'] = df['rating_number'].apply(pd.to_numeric, errors='coerce')
    matching_rows = df[df['parent_asin'].isin(community_asins)]
    
    deduped = matching_rows.sort_values('rating_number', ascending=False).drop_duplicates('parent_asin')
    
    top_rows = deduped.sort_values('rating_number', ascending=False)
    top_rows = top_rows[top_rows['movie_title'].notna()]
    
    seen = set()
    unique_top_titles = []
    
    for _, row in top_rows.iterrows():
        norm_title = normalize_title(row['movie_title'])
        if norm_title not in seen:
            seen.add(norm_title)
            unique_top_titles.append((row['movie_title'], row['rating_number']))
        if len(unique_top_titles) >= top_n:
            break

    return unique_top_titles

# %%
# Test it here:
community_id = 10
asin_list = communities[community_id]
top_titles = get_top_titles_for_community(asin_list, df)
for t in top_titles:
    print(t)
# Out:
# ('Elf (DVD)', 123483.0)
# ('Buena Vista Home Video, Hocus Pocus', 85704.0)
# ('Bohemian Rhapsody [Blu-ray]', 81249.0)
# ('Once upon a Time in Hollywood', 81153.0)
# ('News of the World [DVD]', 59395.0)
# ('The Nightmare Before Christmas', 54779.0)
# ('Get Out [DVD]', 52876.0)
# ("Avatar (Three-Disc Extended Collector's Edition)", 52341.0)
# ('A Beautiful Day in the Neighborhood', 47823.0)
# ('Fantastic Beasts: The Crimes of Grindelwald (DVD)', 45964.0)

# %%
# This code block filters the top tiles WITH the top genre to get a better
# overview of the type of movie in a community. Why? Because the communities generally
# Share genres like action/drama so the same types of movies will otherwise dominate
# in every communities top hits.

def get_top_titles_by_genre_for_community(community_asins, df, asin_to_categories, top_n=10):
    # First get the top genre for this community
    top_genres = get_top_genres_for_community(community_asins, asin_to_categories, 1)
    top_genre = next(iter(top_genres.keys()))
    
    # Get matching rows for this community
    matching_rows = df[df['parent_asin'].isin(community_asins)]
    
    # Filter rows that have the top genre in their categories
    filtered_rows = []
    for _, row in matching_rows.iterrows():
        categories = asin_to_categories.get(row['parent_asin'], [])
        categories_lower = [cat.lower() for cat in categories]
        if any(top_genre in cat for cat in categories_lower):
            filtered_rows.append(row)
    
    # Create a DataFrame from filtered rows
    filtered_df = pd.DataFrame(filtered_rows)
    
    # Deduplicate and sort by rating_number
    deduped = filtered_df.sort_values('rating_number', ascending=False).drop_duplicates('parent_asin')
    top_rows = deduped.sort_values('rating_number', ascending=False)
    top_rows = top_rows[top_rows['movie_title'].notna()]
    
    # Get unique titles
    seen = set()
    unique_top_titles = []
    
    for _, row in top_rows.iterrows():
        norm_title = normalize_title(row['movie_title'])
        if norm_title not in seen:
            seen.add(norm_title)
            unique_top_titles.append((row['movie_title'], row['rating_number']))
        if len(unique_top_titles) >= top_n:
            break

    return unique_top_titles, top_genre

# %%
community_id = 6
asin_list = communities[community_id]
top_titles, top_genre = get_top_titles_by_genre_for_community(asin_list, df, asin_to_categories, 10)

print(f"Top {top_genre} movies in community {community_id}:")
for title, rating_count in top_titles:
    print(f"  > {title} (Ratings: {rating_count})")
# Out:
# Top science fiction movies in community 6:
#   > Star Trek (Two-Disc Edition) (Ratings: 28422.0)
#   > Shrek 2 (Widescreen Edition) (Ratings: 25002.0)
#   > Iron Man (Ultimate 2 Disc Edition) (Ratings: 21704.0)
#   > Unbreakable (Two-Disc Vista Series) (Ratings: 20912.0)
#   > Blade Runner (Four-Disc Collector's Edition) (Ratings: 20471.0)
#   > Transformers: Revenge of the Fallen (Ratings: 19375.0)
#   > Star Wars: The Original Trilogy (Episodes IV-VI) [Region 2 DVD] (Ratings: 17015.0)
#   > Armageddon (Ratings: 16047.0)
#   > War of the Worlds (Ratings: 15510.0)
#   > The Last Starfighter (Ratings: 12599.0)

# %% [markdown]
# Community 0: training style movies.
#
# Community 1: popular action type movies.
#
# Community 2: More popular action movies, not sure what the difference is with 1.
#
# Community 3: Comedy movies, christmas movies are the most popular
#
# Community 4: Drama stuff
#
# Community 5: More drama stuff.
#
# Community 6: Predominantly Science Fiction adjacent stuff (and shrek 2)
